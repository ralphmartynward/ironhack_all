# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
# !pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.26.15)
# Collecting async-timeout>=4.0.2 (from redis>=3.5.3->spotipy)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.2 redis-4.5.4 spotipy-2.23.0

# %% [markdown]
# ## Loading credentials from another config file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(1, '/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ## Starting with Spotify API

# %% [markdown]
# **Caution!!!**
#
# Spotify API has a limit of the number of calls made every 30 seconds. If you exceed this limit, you will get a "429" error code and you will have to wait several hours to be able to make new requests.
#
# Be extremelly carefull to avoid this problem.

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias # 
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="tracks:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q="Yann Tiersen", limit=5)
#results
#results.keys()
results['tracks']['items'][0]['album']['artists'][0]
#results['tracks']['items'][0]['album']['artists'][0]
#results['tracks']['items'][0]['album']['artists'][0]
#results['tracks']['items'][0]['album']['artists'][0]
#results['tracks']['items'][0]['album'].keys()
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['album']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#  'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#  'id': '00sazWvoTLOqg5MFwC68Um',
#  'name': 'Yann Tiersen',
#  'type': 'artist',
#  'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}

# %% [markdown]
# {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5',
#             'items': [{'album': {'album_group': 'album',
#                                  'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CD',
#                                                        'CG',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'ET',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IQ',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'LY',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TJ',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VE',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#                                  'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#                                  'id': '6PRPYATK5VvjZ2p911y6U0',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#                                              'width': 64}],
#                                  'name': "Le Fabuleux destin d'Amélie Poulain "
#                                          '(Bande originale du film)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 140733,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100002'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#                        'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#                        'id': '14rZjW3RioG7WesZhYESso',
#                        'is_local': False,
#                        'name': "Comptine d'un autre été, l'après-midi",
#                        'popularity': 74,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/df24e196f6607178532177beefb9acf8b73fa68b?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'},
#                       {'album': {'album_group': 'album',
#                                  'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CD',
#                                                        'CG',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'ET',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IQ',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'LY',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TJ',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VE',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#                                  'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#                                  'id': '6PRPYATK5VvjZ2p911y6U0',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#                                              'width': 64}],
#                                  'name': "Le Fabuleux destin d'Amélie Poulain "
#                                          '(Bande originale du film)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 158666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100008'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq'},
#                        'href': 'https://api.spotify.com/v1/tracks/6bpmBNPfQ2KFAW0ik6F9Vq',
#                        'id': '6bpmBNPfQ2KFAW0ik6F9Vq',
#                        'is_local': False,
# ...
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#                                  'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#                                  'id': '6PRPYATK5VvjZ2p911y6U0',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#                                              'width': 64}],
#                                  'name': "Le Fabuleux destin d'Amélie Poulain "
#                                          '(Bande originale du film)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 135906,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100001'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7MIN37CiVP1lVjqKNmLMWk'},
#                        'href': 'https://api.spotify.com/v1/tracks/7MIN37CiVP1lVjqKNmLMWk',
#                        'id': '7MIN37CiVP1lVjqKNmLMWk',
#                        'is_local': False,
#                        'name': "La valse d'Amélie",
#                        'popularity': 60,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/afe0f7d53cf83441f8e4be991ce95bfc3e9287bd?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:7MIN37CiVP1lVjqKNmLMWk'},
#                       {'album': {'album_group': 'album',
#                                  'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': [],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6Lhd6tN5IW7Ou3ZtX1MGFF'},
#                                  'href': 'https://api.spotify.com/v1/albums/6Lhd6tN5IW7Ou3ZtX1MGFF',
#                                  'id': '6Lhd6tN5IW7Ou3ZtX1MGFF',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273db0698399ae52fbd642c9d0a',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02db0698399ae52fbd642c9d0a',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851db0698399ae52fbd642c9d0a',
#                                              'width': 64}],
#                                  'name': 'Tabarly (Original Motion Picture '
#                                          'Soundtrack)',
#                                  'release_date': '2008-06-16',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6Lhd6tN5IW7Ou3ZtX1MGFF'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': [],
#                        'disc_number': 1,
#                        'duration_ms': 92093,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR26S0800039'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1QA5ZGzFfVKoITIPZXFDDU'},
#                        'href': 'https://api.spotify.com/v1/tracks/1QA5ZGzFfVKoITIPZXFDDU',
#                        'id': '1QA5ZGzFfVKoITIPZXFDDU',
#                        'is_local': False,
#                        'name': 'Dernière',
#                        'popularity': 49,
#                        'preview_url': None,
#                        'track_number': 13,
#                        'type': 'track',
#                        'uri': 'spotify:track:1QA5ZGzFfVKoITIPZXFDDU'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 1000}}

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#    'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#    'id': '6PRPYATK5VvjZ2p911y6U0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#      'width': 64}],
#    'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 140733,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100002'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#   'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#   'id': '14rZjW3RioG7WesZhYESso',
#   'is_local': False,
#   'name': "Comptine d'un autre été, l'après-midi",
#   'popularity': 74,
#   'preview_url': 'https://p.scdn.co/mp3-preview/df24e196f6607178532177beefb9acf8b73fa68b?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#    'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#    'id': '6PRPYATK5VvjZ2p911y6U0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#      'width': 64}],
#    'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 158666,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100008'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq'},
#   'href': 'https://api.spotify.com/v1/tracks/6bpmBNPfQ2KFAW0ik6F9Vq',
#   'id': '6bpmBNPfQ2KFAW0ik6F9Vq',
#   'is_local': False,
#   'name': "La Valse d'Amélie - Version piano",
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2b3a4c59666bbbc9441ef29cb2105d8732c93c13?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:6bpmBNPfQ2KFAW0ik6F9Vq'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6Xk1BYolSr352WvpfwWLZq'},
#    'href': 'https://api.spotify.com/v1/albums/6Xk1BYolSr352WvpfwWLZq',
#    'id': '6Xk1BYolSr352WvpfwWLZq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730abfcb9a35c4b084efc287d9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020abfcb9a35c4b084efc287d9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510abfcb9a35c4b084efc287d9',
#      'width': 64}],
#    'name': 'Goodbye Lenin !',
#    'release_date': '2003-02-03',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:6Xk1BYolSr352WvpfwWLZq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 88546,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRS940200080'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/35fKXUJk1yDn3LVr6MbSHm'},
#   'href': 'https://api.spotify.com/v1/tracks/35fKXUJk1yDn3LVr6MbSHm',
#   'id': '35fKXUJk1yDn3LVr6MbSHm',
#   'is_local': False,
#   'name': "Mother's Journey",
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dbde53c53683df6033e97aa81b18c5a99a8ed191?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:35fKXUJk1yDn3LVr6MbSHm'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#    'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#    'id': '6PRPYATK5VvjZ2p911y6U0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#      'width': 64}],
#    'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 135906,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7MIN37CiVP1lVjqKNmLMWk'},
#   'href': 'https://api.spotify.com/v1/tracks/7MIN37CiVP1lVjqKNmLMWk',
#   'id': '7MIN37CiVP1lVjqKNmLMWk',
#   'is_local': False,
#   'name': "La valse d'Amélie",
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/afe0f7d53cf83441f8e4be991ce95bfc3e9287bd?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7MIN37CiVP1lVjqKNmLMWk'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6Lhd6tN5IW7Ou3ZtX1MGFF'},
#    'href': 'https://api.spotify.com/v1/albums/6Lhd6tN5IW7Ou3ZtX1MGFF',
#    'id': '6Lhd6tN5IW7Ou3ZtX1MGFF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273db0698399ae52fbd642c9d0a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02db0698399ae52fbd642c9d0a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851db0698399ae52fbd642c9d0a',
#      'width': 64}],
#    'name': 'Tabarly (Original Motion Picture Soundtrack)',
#    'release_date': '2008-06-16',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6Lhd6tN5IW7Ou3ZtX1MGFF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': [],
#   'disc_number': 1,
#   'duration_ms': 92093,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR26S0800039'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1QA5ZGzFfVKoITIPZXFDDU'},
#   'href': 'https://api.spotify.com/v1/tracks/1QA5ZGzFfVKoITIPZXFDDU',
#   'id': '1QA5ZGzFfVKoITIPZXFDDU',
#   'is_local': False,
#   'name': 'Dernière',
#   'popularity': 49,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:1QA5ZGzFfVKoITIPZXFDDU'}]

# %%
len(results['tracks']['items'])
# Out:
# 5

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#   'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#   'id': '6PRPYATK5VvjZ2p911y6U0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#     'width': 64}],
#   'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#   'release_date': '2001-04-23',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#    'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#    'id': '00sazWvoTLOqg5MFwC68Um',
#    'name': 'Yann Tiersen',
#    'type': 'artist',
#    'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 140733,
#  'explicit': False,
#  'external_ids': {'isrc': 'FR91U0100002'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#  'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#  'id': '14rZjW3RioG7WesZhYESso',
#  'is_local': False,
#  'name': "Comptine d'un autre été, l'après-midi",
#  'popularity': 74,
#  'preview_url': 'https://p.scdn.co/mp3-preview/df24e196f6607178532177beefb9acf8b73fa68b?cid=0912c34e16c349f28a330c0eba3cc52f',
#  'track_number': 3,
#  'type': 'track',
#  'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['id']
# Out:
# '14rZjW3RioG7WesZhYESso'

# %%
try: 
    results = sp.search(q="Imagine", limit=5)
except:
    id = "None"

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['id']))
# Out:
# The name of song is: 'Imagine - Remastered 2010' and the id is: 7pKfPomDEeI4TPT6EOYjn9
# The name of song is: 'Believer' and the id is: 0pqnGHJpmpxLKifKRmU6WP
# The name of song is: 'Bones' and the id is: 54ipXppHLA8U4yqpOFTUhr
# The name of song is: 'imagine' and the id is: 39LmTF9RgyakzSYX8txrow
# The name of song is: 'Bones' and the id is: 0HqZX76SFLDz2aW8aiqi7G

# %%
results["tracks"]["items"][0]['name']
# Out:
# 'Imagine - Remastered 2010'

# %%
import pandas as pd

song = sp.search(q="comptine d'un autre été", limit=1) 
#song['tracks']['items'][0]['uri']
#pprint.pprint(song['tracks']['items'][0]['uri'])
#song['tracks']['items'][0]['uri']
#song["tracks"]["items"][0]["uri"]
#sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

#print(my_dict)
my_dict_new = { key : [my_dict[key]] for key in list(my_dict.keys()) }
#print(my_dict_new)
my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)
# Out:
# {'danceability': [0.483], 'energy': [0.192], 'key': [4], 'loudness': [-15.378], 'mode': [0], 'speechiness': [0.0469], 'acousticness': [0.991], 'instrumentalness': [0.908], 'liveness': [0.106], 'valence': [0.0542], 'tempo': [100.848], 'type': ['audio_features'], 'id': ['14rZjW3RioG7WesZhYESso'], 'uri': ['spotify:track:14rZjW3RioG7WesZhYESso'], 'track_href': ['https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/14rZjW3RioG7WesZhYESso'], 'duration_ms': [140733], 'time_signature': [4], 'name': ["Comptine d'un autre été, l'après-midi"]}
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.483   0.192    4   -15.378     0       0.0469         0.991
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0             0.908     0.106   0.0542  100.848  audio_features
#
#                        id                                   uri  \
# 0  14rZjW3RioG7WesZhYESso  spotify:track:14rZjW3RioG7WesZhYESso
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/14rZjW3RioG7...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/14rZ...       140733
#
#    time_signature                                   name
# 0               4  Comptine d'un autre été, l'après-midi

# %%
#df.iloc[:100,0], df.iloc[:100,1]

# %%
# create "chunks" of 50-100 songs
for chunk in chunks:
     # print("Retrieving id from chunk {}".format())
    try: # if everything goes well
        # get_song_id() uri/id
        # add song_id to the list
    except: # else:
        # song_id = ""
        # add song_id to the list
        # print("Song not found")
    # sleep(10)

# Remove songs with sond_id = "" 
for id in chunk_list_of_ids:
    # print("Retrieving audio_features from chunk {}".format())
    # get audio_features
    # add_audio_features to df
    # sleep(10)

# %% [markdown]
# The meaning of Spotify audio features can be found [here](https://developer.spotify.com/discover/) and [here](https://www.therecordindustry.io/spotify-audio-features/)

# %% [markdown]
# Let's search for songs of several artists

# %%
my_artists = ['Placebo','Marylin Manson','Janis Joplin']

my_dict = {}
#for artist in my_artists:
#    #result = sp.search(q=artist, limit= 50)
#    my_dict[artist] = sp.search(q=artist, limit= 50)

my_dict = {artist: sp.search(q=artist, limit= 50) for artist in my_artists}
#my_dict
my_dict.keys()
# Out:
# dict_keys(['Placebo', 'Marylin Manson', 'Janis Joplin'])

# %%
len(my_dict['Janis Joplin']['tracks']['items'])
# Out:
# 50

# %%
type(my_dict['Janis Joplin']['tracks']['items'][0])
# Out:
# dict

# %%
my_dict['Janis Joplin']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
sp.search(q="Janis Joplin", limit= 5)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Janis+Joplin&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j7nicLAWXM0Fb08q9XGyf'},
#      'href': 'https://api.spotify.com/v1/albums/3j7nicLAWXM0Fb08q9XGyf',
#      'id': '3j7nicLAWXM0Fb08q9XGyf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f8c26346723dd0531696bed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f8c26346723dd0531696bed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f8c26346723dd0531696bed',
#        'width': 64}],
#      'name': 'Pearl (Legacy Edition)',
#      'release_date': '1971-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:3j7nicLAWXM0Fb08q9XGyf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#       'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#       'id': '4NgfOZCL9Ml67xzM0xzIvC',
#       'name': 'Janis Joplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 271333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM17000790'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IqFh00G2kvvMm8pRMpehA'},
#     'href': 'https://api.spotify.com/v1/tracks/1IqFh00G2kvvMm8pRMpehA',
#     'id': '1IqFh00G2kvvMm8pRMpehA',
#     'is_local': False,
#     'name': 'Me and Bobby McGee',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/12be57eefcb8ad3d228b2feb26d5be92da38b0ff?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1IqFh00G2kvvMm8pRMpehA'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0xHBgcc8mjG1FILI9NPrg9'},
#      'href': 'https://api.spotify.com/v1/albums/0xHBgcc8mjG1FILI9NPrg9',
#      'id': '0xHBgcc8mjG1FILI9NPrg9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273925dd54f56617efcf7b75d8b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02925dd54f56617efcf7b75d8b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851925dd54f56617efcf7b75d8b',
#        'width': 64}],
#      'name': 'Flash Back Internacional',
#      'release_date': '2018-04-27',
#      'release_date_precision': 'day',
#      'total_tracks': 36,
#      'type': 'album',
#      'uri': 'spotify:album:0xHBgcc8mjG1FILI9NPrg9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#       'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#       'id': '4NgfOZCL9Ml67xzM0xzIvC',
#       'name': 'Janis Joplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 266240,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM16800240'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3V3MQOlQqq8SZ7BcoN4QCn'},
#     'href': 'https://api.spotify.com/v1/tracks/3V3MQOlQqq8SZ7BcoN4QCn',
#     'id': '3V3MQOlQqq8SZ7BcoN4QCn',
#     'is_local': False,
#     'name': 'Piece of My Heart',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53638cf509cb789b7da3d7b8a07ac8c5503d1014?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 32,
#     'type': 'track',
#     'uri': 'spotify:track:3V3MQOlQqq8SZ7BcoN4QCn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#        'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#        'id': '4J69yWrKwWJgjv3DKTZcGo',
#        'name': 'Big Brother & The Holding Company',
#        'type': 'artist',
#        'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2rogKfOpmCFuqNhtGKf2dX'},
#      'href': 'https://api.spotify.com/v1/albums/2rogKfOpmCFuqNhtGKf2dX',
#      'id': '2rogKfOpmCFuqNhtGKf2dX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731ba5ee8bc24979ce3eee4797',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021ba5ee8bc24979ce3eee4797',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511ba5ee8bc24979ce3eee4797',
#        'width': 64}],
#      'name': 'Cheap Thrills',
#      'release_date': '1968-08-12',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2rogKfOpmCFuqNhtGKf2dX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#       'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#       'id': '4J69yWrKwWJgjv3DKTZcGo',
#       'name': 'Big Brother & The Holding Company',
#       'type': 'artist',
#       'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#       'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#       'id': '4NgfOZCL9Ml67xzM0xzIvC',
#       'name': 'Janis Joplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 253333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM16800982'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xKQbqQtQWrtQS47fUJBtl'},
#     'href': 'https://api.spotify.com/v1/tracks/1xKQbqQtQWrtQS47fUJBtl',
#     'id': '1xKQbqQtQWrtQS47fUJBtl',
#     'is_local': False,
#     'name': 'Piece of My Heart',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9edfbc51c60e42e817da01350955d6757a2ebd3b?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1xKQbqQtQWrtQS47fUJBtl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j7nicLAWXM0Fb08q9XGyf'},
#      'href': 'https://api.spotify.com/v1/albums/3j7nicLAWXM0Fb08q9XGyf',
#      'id': '3j7nicLAWXM0Fb08q9XGyf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f8c26346723dd0531696bed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f8c26346723dd0531696bed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f8c26346723dd0531696bed',
#        'width': 64}],
#      'name': 'Pearl (Legacy Edition)',
#      'release_date': '1971-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:3j7nicLAWXM0Fb08q9XGyf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#       'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#       'id': '4NgfOZCL9Ml67xzM0xzIvC',
#       'name': 'Janis Joplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 238600,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM17000785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3L60Vu9qmY6fg2QroRIxgi'},
#     'href': 'https://api.spotify.com/v1/tracks/3L60Vu9qmY6fg2QroRIxgi',
#     'id': '3L60Vu9qmY6fg2QroRIxgi',
#     'is_local': False,
#     'name': 'Cry Baby',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4a1a4ca370d57cfb204c3606d792d7a010daaa2e?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3L60Vu9qmY6fg2QroRIxgi'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j7nicLAWXM0Fb08q9XGyf'},
#      'href': 'https://api.spotify.com/v1/albums/3j7nicLAWXM0Fb08q9XGyf',
#      'id': '3j7nicLAWXM0Fb08q9XGyf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f8c26346723dd0531696bed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f8c26346723dd0531696bed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f8c26346723dd0531696bed',
#        'width': 64}],
#      'name': 'Pearl (Legacy Edition)',
#      'release_date': '1971-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:3j7nicLAWXM0Fb08q9XGyf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#       'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#       'id': '4NgfOZCL9Ml67xzM0xzIvC',
#       'name': 'Janis Joplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 107866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10408486'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1MntHPLU1T7a9W4tojbg8g'},
#     'href': 'https://api.spotify.com/v1/tracks/1MntHPLU1T7a9W4tojbg8g',
#     'id': '1MntHPLU1T7a9W4tojbg8g',
#     'is_local': False,
#     'name': 'Mercedes Benz',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/180d95d2a79dc590706d221dad273a0b47105c13?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1MntHPLU1T7a9W4tojbg8g'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=Janis+Joplin&type=track&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you may want to consider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Imagine&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'},
#        'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H',
#        'id': '4x1nvY2FN8jxqAFA0DA02H',
#        'name': 'John Lennon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0xzaemKucrJpYhyl7TltAk'},
#      'href': 'https://api.spotify.com/v1/albums/0xzaemKucrJpYhyl7TltAk',
#      'id': '0xzaemKucrJpYhyl7TltAk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399581550ef9746ca582bb3cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299581550ef9746ca582bb3cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199581550ef9746ca582bb3cc',
#        'width': 64}],
#      'name': 'Imagine',
#      'release_date': '1971-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0xzaemKucrJpYhyl7TltAk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'},
#       'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H',
#       'id': '4x1nvY2FN8jxqAFA0DA02H',
#       'name': 'John Lennon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 187866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1000769'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7pKfPomDEeI4TPT6EOYjn9'},
#     'href': 'https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9',
#     'id': '7pKfPomDEeI4TPT6EOYjn9',
#     'is_local': False,
#     'name': 'Imagine - Remastered 2010',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3ecb8ff1dcc79c652a16b37dd2a54438715020e3?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7pKfPomDEeI4TPT6EOYjn9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Q9SnHWPNEjVM0LrBFvJ1q'},
#      'href': 'https://api.spotify.com/v1/albums/1Q9SnHWPNEjVM0LrBFvJ1q',
#      'id': '1Q9SnHWPNEjVM0LrBFvJ1q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273813713582dcc508e7d5073c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02813713582dcc508e7d5073c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851813713582dcc508e7d5073c4',
#        'width': 64}],
#      'name': 'Bones',
#      'release_date': '2022-03-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1Q9SnHWPNEjVM0LrBFvJ1q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165264,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72201759'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0HqZX76SFLDz2aW8aiqi7G'},
#     'href': 'https://api.spotify.com/v1/tracks/0HqZX76SFLDz2aW8aiqi7G',
#     'id': '0HqZX76SFLDz2aW8aiqi7G',
#     'is_local': False,
#     'name': 'Bones',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d6d966b718729ff8b0a251eb4eb272ff4d13fc0?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0HqZX76SFLDz2aW8aiqi7G'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33pt9HBdGlAbRGBHQgsZsU'},
#      'href': 'https://api.spotify.com/v1/albums/33pt9HBdGlAbRGBHQgsZsU',
#      'id': '33pt9HBdGlAbRGBHQgsZsU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735675e83f707f1d7271e5cf8a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515675e83f707f1d7271e5cf8a',
#        'width': 64}],
#      'name': 'Evolve',
#      'release_date': '2017-06-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:33pt9HBdGlAbRGBHQgsZsU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204346,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71700626'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0pqnGHJpmpxLKifKRmU6WP'},
#     'href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP',
#     'id': '0pqnGHJpmpxLKifKRmU6WP',
#     'is_local': False,
#     'name': 'Believer',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec88376e0fe562c6577468502ae73d79c14ded21?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6yiXkzHvC0OTmhfDQOEWtS'},
#      'href': 'https://api.spotify.com/v1/albums/6yiXkzHvC0OTmhfDQOEWtS',
#      'id': '6yiXkzHvC0OTmhfDQOEWtS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc915b69600dce2991a61f13',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc915b69600dce2991a61f13',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc915b69600dce2991a61f13',
#        'width': 64}],
#      'name': 'Mercury - Acts 1 & 2',
#      'release_date': '2022-07-01',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:6yiXkzHvC0OTmhfDQOEWtS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 165264,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72201759'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54ipXppHLA8U4yqpOFTUhr'},
#     'href': 'https://api.spotify.com/v1/tracks/54ipXppHLA8U4yqpOFTUhr',
#     'id': '54ipXppHLA8U4yqpOFTUhr',
#     'is_local': False,
#     'name': 'Bones',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/95af8a79caa005b5332e3583de6ae67614ad4a07?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:54ipXppHLA8U4yqpOFTUhr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#      'href': 'https://api.spotify.com/v1/albums/2fYhqwDWXjbpjaIJPEfKFw',
#      'id': '2fYhqwDWXjbpjaIJPEfKFw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27356ac7b86e090f307e218e9c8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0256ac7b86e090f307e218e9c8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485156ac7b86e090f307e218e9c8',
#        'width': 64}],
#      'name': 'thank u, next',
#      'release_date': '2019-02-08',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2fYhqwDWXjbpjaIJPEfKFw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 212266,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71822236'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/39LmTF9RgyakzSYX8txrow'},
#     'href': 'https://api.spotify.com/v1/tracks/39LmTF9RgyakzSYX8txrow',
#     'id': '39LmTF9RgyakzSYX8txrow',
#     'is_local': False,
#     'name': 'imagine',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2eb267fde40457b452b5e00f13f2e64073f973c2?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:39LmTF9RgyakzSYX8txrow'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=Imagine&type=track&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Imagine&type=track&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0xzaemKucrJpYhyl7TltAk'}, 'href': 'https://api.spotify.com/v1/albums/0xzaemKucrJpYhyl7TltAk', 'id': '0xzaemKucrJpYhyl7TltAk', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27399581550ef9746ca582bb3cc', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0299581550ef9746ca582bb3cc', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485199581550ef9746ca582bb3cc', 'width': 64}], 'name': 'Imagine', 'release_date': '1971-09-09', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:0xzaemKucrJpYhyl7TltAk'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 187866, 'explicit': False, 'external_ids': {'isrc': 'GBAYE1000769'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/7pKfPomDEeI4TPT6EOYjn9'}, 'href': 'https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9', 'id': '7pKfPomDEeI4TPT6EOYjn9', 'is_local': False, 'name': 'Imagine - Remastered 2010', 'popularity': 74, 'preview_url': 'https://p.scdn.co/mp3-preview/ ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=Imagine&type=track&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  1000

# %% [markdown]
# ## Exploring the tracks

# %%
print("Total number of tracks: ",len(results["tracks"]["items"])) # 50 Tracks (as limited, it is the maximum)
print("Info of the first song: ",results["tracks"]["items"][0]) # Explore the first song 
print("The keys of the dictionary are: ",list(results["tracks"]["items"][0].keys())) # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# Total number of tracks:  5
# Info of the first song:  {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0xzaemKucrJpYhyl7TltAk'}, 'href': 'https://api.spotify.com/v1/albums/0xzaemKucrJpYhyl7TltAk', 'id': '0xzaemKucrJpYhyl7TltAk', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27399581550ef9746ca582bb3cc', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0299581550ef9746ca582bb3cc', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485199581550ef9746ca582bb3cc', 'width': 64}], 'name': 'Imagine', 'release_date': '1971-09-09', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:0xzaemKucrJpYhyl7TltAk'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 187866, 'explicit': False, 'external_ids': {'isrc': 'GBAYE1000769'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/7pKfPomDEeI4TPT6EOYjn9'}, 'href': 'https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9', 'id': '7pKfPomDEeI4TPT6EOYjn9', 'is_local': False, 'name': 'Imagine - Remastered 2010', 'popularity': 74, 'preview_url': 'https://p.scdn.co/mp3-preview/3ecb8ff1dc ...
# The keys of the dictionary are:  ['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri']

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
print(results["tracks"]["items"][0]["album"]["release_date"]) #date in YYYY-MM-DD format
print("Songs in the album: ",results["tracks"]["items"][0]["album"]["total_tracks"]) #songs in the album
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0xzaemKucrJpYhyl7TltAk'}, 'href': 'https://api.spotify.com/v1/albums/0xzaemKucrJpYhyl7TltAk', 'id': '0xzaemKucrJpYhyl7TltAk', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27399581550ef9746ca582bb3cc', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0299581550ef9746ca582bb3cc', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485199581550ef9746ca582bb3cc', 'width': 64}], 'name': 'Imagine', 'release_date': '1971-09-09', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:0xzaemKucrJpYhyl7TltAk'}
# ['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}]
# The album ID is:  0xzaemKucrJpYhyl7TltAk
# Imagine
# 1971-09-09
# Songs in the album:  10

# %% [markdown]
# ## Other info

# %%
print("Artists: ",results["tracks"]["items"][0]["artists"]) # Track artists
print("Song id is : ",results["tracks"]["items"][0]["id"]) # Track ID
print("Song name is: ",results["tracks"]["items"][0]["name"]) # Track name
print("Song popularity index is: ",results["tracks"]["items"][0]["popularity"]) # Popularity index
print("Song uri: ",results["tracks"]["items"][0]["uri"]) # Basically ID
print("Song href: ",results["tracks"]["items"][0]["href"]) # Href
# Out:
# Artists:  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'}, 'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H', 'id': '4x1nvY2FN8jxqAFA0DA02H', 'name': 'John Lennon', 'type': 'artist', 'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}]
# Song id is :  7pKfPomDEeI4TPT6EOYjn9
# Song name is:  Imagine - Remastered 2010
# Song popularity index is:  74
# Song uri:  spotify:track:7pKfPomDEeI4TPT6EOYjn9
# Song href:  https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9

# %% [markdown]
# # Exploring songs

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.8/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-50-846c04166b3c> in <module>
# ----> 1 playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
#
# /usr/local/lib/python3.8/dist-packages/spotipy/client.py in user_playlist_tracks(self, user, playlist_id, fields, limit, offset, market)
#     777                 - market - an ISO 3166-1 alpha-2 country code.
#     778         """
# --> 779         return self.playlist_tracks(
#     780             playlist_id,
#     781             limit=limit,
#
# /usr/local/lib/python3.8/dist-packages/spotipy/client.py in playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     679             DeprecationWarning,
#     680         )
# --> 681         return self.playlist_items(playlist_id, fields, limit, offset,
#     682                                    market, additional_types)
#     683
#
# /usr/local/lib/python3.8/dist-packages/spotipy/client.py in playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     703         """
#     704         plid = self._get_id("playlist", playlist_id)
# --> 705         return self._get(
#     706             "playlists/%s/tracks" % (plid),
#     707             limit=limit,
#
# /usr/local/lib/python3.8/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# --> 321         return self._internal_call("GET", url, payload, kwargs)
#     322
#     323     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     262
#     263         try:
# --> 264             response = self._session.request(
#     265                 method, url, headers=headers, proxies=self.proxies,
#     266                 timeout=self.requests_timeout, **args
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.8/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %%
type(playlist)
# Out:
# dict

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5295
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'Ryan Riback',
#  'TobyMac',
#  'Life of Boris',
#  'Etham',
#  'OMC',
#  'Protoculture',
#  'Trippie Redd',
#  'Jonna Tervomaa',
#  'Sofia Carson',
#  'Rosette',
#  'Aurora',
#  'Jay Park',
#  'Mathieu Koss',
#  'Nopsajalka',
#  'Waterparks',
#  'Spice Girls',
#  'Hätä-Miikka',
#  'J Spooks',
#  'Ali Gatie',
#  'Alina Baraz',
#  'Herba',
#  'Kalle Lindroth',
#  'Dove Cameron',
#  'Vanilla Ice',
#  'Spree Wilson',
#  'Timmies',
#  'House Of Pain',
#  'The Moose',
#  '6LACK',
#  'Era Istrefi',
#  'Pää-äijät',
#  'Taikapeili',
#  'líue',
#  'Freddo',
#  'Bonnie Tyler',
#  'Juno',
#  'Rod Wave',
#  'Ness The Kid',
#  'Ida Paul',
#  'Wiley',
#  'Gente De Zona',
#  'Linkin Park',
#  'Jorma Uotinen',
#  'Kansas',
#  'Kid Cudi',
#  'Chris Willis',
#  'Daze',
#  'beabadoobee',
#  'D.O.E.',
#  'Hey Violet',
#  'Comethazine',
#  'CALVO',
#  'Elias Gould',
#  'Skandaali',
#  'Suvi Teräsniska',
#  'Pyhimys',
#  'Nate Dogg',
#  'Internet Money',
#  'Justin Mylo',
#  'Drenchill',
#  'Michael Bolton',
#  'Måns Zelmerlöw',
#  'Dirty Disco Youth',
#  'Elena Coats',
#  'Michelle Williams',
#  'Rich The Kid',
#  'Trinidad Cardona',
#  'Marvin Gaye',
#  'Ray J',
#  'Zeeba',
#  'LIL MAYO',
#  'Lilly Wood and The Prick',
#  'Megan Nicole',
#  'E-40',
#  'Christina Aguilera',
#  'Oso Faneto',
#  'BETWEEN FRIENDS',
#  'Good Times Ahead',
#  'Post Malone',
#  'Faul & Wad',
#  'Sound Of Legend',
#  'Pekka Ruuska',
#  'Gus Dapperton',
#  'Lil Rain',
#  'EDEN',
#  'Paloma Faith',
#  'Keko Salata',
#  'lovelytheband',
#  'S.Pri Noir',
#  'Etta',
#  'Faydee',
#  'ARTY',
#  'Gwen Stefani',
#  'Ne-Yo',
#  'Armin van Buuren',
#  'A$AP Ferg',
#  'Jay Prince',
#  'Thomas Rhett',
#  'M-Fuse',
#  'Pouya',
#  'FRENSHIP',
#  'Savage',
#  'Aku Hirviniemi',
#  'Lil Sage x JustSeAbu x MVD J€¥$ON',
#  'The Offspring',
#  'Freddie Dredd',
#  'Survivor',
#  'DallasK',
#  'Josh A',
#  'Cheat Codes',
#  'Daniel Okas',
#  'Good Charlotte',
#  'Journey',
#  'Vanessa Carlton',
#  'Alexander Tidebrink',
#  'Bryson Tiller',
#  'Sash!',
#  'Treyy G',
#  'Shania Twain',
#  'DEM',
#  'Kurupt',
#  'LP',
#  'Mýa',
#  'Meiju Suvas',
#  'Ruel',
#  'Seeb',
#  'Supergrass',
#  'Devin The Dude',
#  'JP Saxe',
#  'Dakota',
#  'Kacy Hill',
#  'ABREU',
#  'Alex Vargas',
#  'Jope Ruonansuu',
#  '2nen',
#  'eetu',
#  'Sampha',
#  'Anna Puu',
#  '24kGoldn',
#  'Lea in the Mix',
#  'Craig Xen',
#  'Alphaville',
#  'Paradisio',
#  'Hardwell',
#  'Anitta',
#  'Fernando',
#  'Jhayco',
#  'Lil Jon & The East Side Boyz',
#  'The Corrs',
#  'Gunna',
#  'Mr. Elämänpeli',
#  'Calpurnia',
#  'Topic',
#  'Riki Sorsa',
#  'Adele',
#  'Danny Avila',
#  'The Boy Next Door',
#  'Sunrise Avenue',
#  'Labrinth',
#  'Ryan Leslie',
#  'Sliki & Hamuelos',
#  'Coldplay',
#  '916frosty',
#  'Ideaali & Jay Who?',
#  'John Legend',
#  'Pekka Kuusisto',
#  'Nate Ruess',
#  'Cordae',
#  'Camila Cabello',
#  'KAMASUTRA 9G',
#  '$NOT',
#  'Big Time Rush',
#  'Lexi Jayde',
#  'KYLE',
#  'Aksel Kankaanranta',
#  'KVR',
#  'Kasmir',
#  'WhoHeem',
#  'Arash',
#  'Todrick Hall',
#  'Lil Kapow',
#  'Ricegum',
#  'Zachary Knowles',
#  'Hozier',
#  'LeAnn Rimes',
#  'Jake Paul',
#  'DJ White Shadow',
#  'The Pussycat Dolls',
#  'Mike Candys',
#  'DROELOE',
#  'T-Pain',
#  'A2M',
#  'AJR',
#  'Cousin Stizz',
#  '$uicideboy$',
#  'Zhavia',
#  'Laurell',
#  'Becky G',
#  'Killua the Pilgrim',
#  'Kill The Noise',
#  'Jhené Aiko',
#  'PUBLIC',
#  'DJ Envy',
#  'The All-American Rejects',
#  'gnash',
#  'Christoph Andersson',
#  'Papa Roach',
#  "Rag'n'Bone Man",
#  'MNEK',
#  'Zoe Nash',
#  'Chrisette Michele',
#  'Danny',
#  'Taio Cruz',
#  'Munamies',
#  'Chivv',
#  "Waldo's People",
#  'Justin Bieber',
#  'Cimo Fränkel',
#  'iamjakehill',
#  'Bobby Burns',
#  'Hausmylly',
#  'Alex Aris',
#  'Alanis Morissette',
#  'Andi',
#  'Busta Rhymes',
#  'Jayceeoh',
#  'Slim Jxmmi',
#  'LiL Lotus',
#  'Lil Wil',
#  'Victorious Cast',
#  'YNW Melly',
#  'Queen',
#  'Little Sis Nora',
#  'Tinie Tempah',
#  'Sini Sabotage',
#  'Stig Dogg',
#  'Cody Simpson',
#  'Bow Wow',
#  'Uniikki',
#  'Katri Helena',
#  'Ida Paul & Kalle Lindroth',
#  'Wheeler Walker Jr.',
#  'Quavo',
#  'Ying Yang Twins',
#  'Simple Plan',
#  'Claire Rosinkranz',
#  'Ayo & Teo',
#  'The Theme Song',
#  'Cameron Kuwada',
#  'Ollie',
#  'Märkä-Simo',
#  'Brayden',
#  'AJ McLean',
#  'Bizi',
#  'M83',
#  'Sander van Doorn',
#  'Marilii',
#  'Kardinal Offishall',
#  'Vory',
#  'Leyla Blue',
#  'X Ambassadors',
#  'Cezinando',
#  'Sweet Baby May',
#  'Piso 21',
#  'Qulinez',
#  'Popeda',
#  'Camila Mendes',
#  'Sean Kingston',
#  'Bizzey',
#  'Bryan Rice',
#  'SZA',
#  'Duki',
#  'Cast of Shake It Up: Break It Down',
#  'Kielijuhani',
#  'Aroc!',
#  'iann dior',
#  'Tom & Hills',
#  'Sima',
#  'MASN',
#  'Baby Tate',
#  'Isac Elliot',
#  'Sean Paul',
#  'Lit',
#  'Madden',
#  'Pete Konemann',
#  'Kimbra',
#  'ILLENIUM',
#  'Stormzy',
#  'Parson James',
#  '6ix9ine',
#  'Kuwada',
#  'Tate McRae',
#  'Martin Garrix',
#  'Kid Bloom',
#  'Faith Evans',
#  'Matchbox Twenty',
#  'Tujamo',
#  'Tyla Yaweh',
#  'Ryan',
#  'Tuure Boelius',
#  'Casso',
#  'Rony Rex',
#  'Michael Andrews',
#  'De La Ghetto',
#  'mysticphonk',
#  'Sami Hedberg',
#  'mansionz',
#  'Tones And I',
#  'Twista',
#  'Selena Gomez & The Scene',
#  'Jack Ü',
#  'Dzeko',
#  'Emily Warren',
#  'Fatman Scoop',
#  'Jennifer Lawrence',
#  '3robi',
#  'Bella Poarch',
#  'Victoria Justice',
#  'Lennon Stella',
#  'Tommy Trash',
#  'BloodPop®',
#  'Laura Närhi',
#  'Mahogany Lox',
#  'Radiohead',
#  'Hannah Robinson',
#  'Haloo Helsinki!',
#  'Current Joys',
#  'S3RL',
#  'James Arthur',
#  'Paleface',
#  'Väinöväinö',
#  'Giveon',
#  'Queen Key',
#  'Lord Est',
#  'Mascolo',
#  'Sugababes',
#  'Jonne Aaron',
#  'Heretic Klick',
#  'Bobby Shmurda',
#  'Ilta',
#  'PistePiste',
#  'Kevin Gates',
#  'Felix Jaehn',
#  'Karri Koira',
#  'Bloodhound Gang',
#  'Lady Leshurr',
#  'Amy Macdonald',
#  'High School Musical Cast',
#  'Mike Cervello',
#  'Hook N Sling',
#  'Freddy Kalas',
#  'Rick Rock',
#  'Petri Nygård',
#  'Smith & Thell',
#  'Diandra',
#  'Gasellit',
#  'The Living Tombstone',
#  'Venior',
#  'Big Sean',
#  'Ellie Goulding',
#  'Eric Nally',
#  'Hurts',
#  'P!nk',
#  'Joseph Williams',
#  'Mike Posner',
#  'Conan Gray',
#  'Danny Quest',
#  'Anssi Kela',
#  'Sultan',
#  'Ilsey',
#  'Majuri',
#  'GAMPER & DADONI',
#  'Ashnikko',
#  'Elokuu',
#  'ScHoolboy Q',
#  'Layton Greene',
#  'Mac DeMarco',
#  'Paramore',
#  'Hazers',
#  'GoonRock',
#  'Rico Nasty',
#  'Gigamesh',
#  'Q-Tip',
#  'Octavian',
#  'Foxes',
#  'Terri B!',
#  'Todiefor',
#  'Kygo',
#  'MGI',
#  'Aki Tykki',
#  'Conor Maynard',
#  'SAARA',
#  'The Weeknd',
#  'Lil Uzi Vert',
#  'SNAP!',
#  'Austin Mahone',
#  'Neljänsuora',
#  'Engelwood',
#  'dodie',
#  'Toby Fox',
#  'Ringnes-Ronny',
#  'Kanye West',
#  'Tony Junior',
#  'Beyoncé',
#  'Master Blaster',
#  'Yello',
#  'Dopant Beats',
#  'Nathan Lane',
#  'Karina',
#  'unheard',
#  'Lil Revive',
#  'Mr. 305',
#  'Benji Reyes',
#  'Sirena',
#  'Bizarre',
#  'Jukka Poika',
#  'Antti Railio',
#  'Travis Barker',
#  'London On Da Track',
#  'Johnta Austin',
#  'Sir Chloe',
#  'The Goo Goo Dolls',
#  'Zendaya',
#  'Cole Swindell',
#  'Röyksopp',
#  'Ashley All Day',
#  'Tears For Fears',
#  'Mouhous',
#  'Kiesza',
#  'Alvaro Soler',
#  'YSN Flow',
#  'Harry Styles',
#  'Playboi Carti',
#  'Amba Shepherd',
#  'Santana',
#  'Oh Wonder',
#  'Poju',
#  'Daniel Caesar',
#  'Willow Sage Hart',
#  'Kendrick Lamar',
#  'Sofia Zida',
#  'Jon-Jon',
#  'Afro Bros',
#  'Fleurie',
#  'Oasis',
#  'Roy Jones Jr.',
#  'Aamupojat',
#  'Sam Smith',
#  'Saara Aalto',
#  'SIDEPIECE',
#  'Becky Hill',
#  'Corona',
#  'Sharon',
#  'Bad Bunny',
#  'kent',
#  'Blush',
#  'Too $hort',
#  'Ja Rule',
#  'Penelope Scott',
#  'Boys Noize',
#  'The Knocks',
#  'VIZE',
#  'Lily Allen',
#  'Jeezy',
#  'Filip Jenven',
#  'K-System',
#  'Jessica Jarrell',
#  'Jordin Sparks',
#  'A$AP Rocky',
#  'Tungevaag',
#  "Destiny's Child",
#  'Natti Natasha',
#  'Niall Horan',
#  'Migos',
#  'Roy Woods',
#  'MOGUAI',
#  'Mike Williams',
#  'CLMD',
#  'Sofi Tukker',
#  'Chisu',
#  'Elley Duhé',
#  'Arttu Wiskari',
#  'Yolanda Be Cool',
#  'LCMDF',
#  'Peter Kuli',
#  'Sirealz',
#  'Zaytoven',
#  'Electric Light Orchestra',
#  'Stefflon Don',
#  'La La La La',
#  'Miley Cyrus',
#  'Gryffin',
#  'Ugly God',
#  'Alexandra Babitzin',
#  'Emeni',
#  'Indica',
#  'Aminé',
#  'Andy Marsh',
#  'Panic! At The Disco',
#  'Sara Bareilles',
#  'Villayn',
#  'FINNEAS',
#  'Doe Boy',
#  'KT Tunstall',
#  'Rebecca Black',
#  'Mura Masa',
#  'Lännen Liinein',
#  'Louis Tomlinson',
#  'Elias Kaskinen & Päivän Sankarit',
#  'Jaden',
#  'Powfu',
#  'Friday Pilots Club',
#  'VilleGalle',
#  'Hughie Thomasson',
#  'Ellinoora',
#  'Glass Animals',
#  'Hittman',
#  'Rodríguez',
#  'Clairo',
#  'Tomppabeats',
#  'Space Cowboy',
#  'Juliette Claire',
#  'Gabriella',
#  'Riverdale Cast',
#  'Robin Thicke',
#  'Mark McCabe',
#  'Aikakone',
#  'Eden Prince',
#  'Olly Murs',
#  'Eyedress',
#  'Deaton Chris Anthony',
#  'Joji',
#  'King Staccz',
#  'The Kid LAROI',
#  'Styles P',
#  '90s Maniacs',
#  'Two Feet',
#  'Dropgun',
#  'XAM',
#  'Cavallini & Shrty',
#  'Pop Smoke',
#  'Facemask Time',
#  'Kiana Ledé',
#  'Classified',
#  'Thirty Seconds To Mars',
#  'TCT',
#  'Maisie Peters',
#  'Anna Järvinen',
#  'Ilkka Vainio',
#  'Thundercat',
#  'BACALL',
#  'Nicky Jam',
#  'Savage Garden',
#  'Infernal',
#  'Cuban Doll',
#  'PSY',
#  'Outkast',
#  'Fleur East',
#  'Blueface',
#  'Lakko',
#  'Little Simz',
#  'Darius & Finlay',
#  'Jason Weaver',
#  'Shortster 0161',
#  'Carly Rae Jepsen',
#  'Swae Lee',
#  'Style of Eye',
#  'Ian Everson',
#  'Alissa Violet',
#  'STIG',
#  'Tyler, The Creator',
#  'Christina Perri',
#  'bbno$',
#  'Sophia Somajo',
#  'Westside Connection',
#  'Nost3 & Protro',
#  'Pitbull',
#  'Jeremy Zucker',
#  'Vance Joy',
#  'Dylan Playfair',
#  'The Companions',
#  'Tainy',
#  'KC',
#  'Masked Wolf',
#  'Juha Tapio',
#  'City Girls',
#  'Vilma Alina',
#  'Metro Station',
#  'Seekae',
#  'The Notorious B.I.G.',
#  'Chance the Rapper',
#  'Valovuosi',
#  'Jay Hardway',
#  'Dean Martin',
#  'Six-Two',
#  'Crazy Town',
#  'Louis The Child',
#  'Daddy Yankee',
#  'Rittz',
#  'Neev',
#  'Dreamer Isioma',
#  'WALK THE MOON',
#  'James Bay',
#  'Dan Caplen',
#  'Omar LinX',
#  'Joe Jonas',
#  'The Flexican',
#  'Flo Milli',
#  'Junge Junge',
#  'Grits',
#  'Fousheé',
#  'iLOVEFRiDAY',
#  'Konsta Original',
#  'Yung Hilly',
#  'Ricky Montgomery',
#  'ROZES',
#  'Riton',
#  'Nico & Vinz',
#  'Seezyn',
#  'OBN Dev',
#  'Culture Beat',
#  'Roscoe Dash',
#  'Michael Schulte',
#  'CJ',
#  'Mikko Harju',
#  'JR Serpent',
#  'Frank Moody',
#  'Richard Smitt',
#  'John Gallagher Jr.',
#  'Toni Wirtanen',
#  'Kuningas Pähkinä & Setä Tamu',
#  'Bipolar Sunshine',
#  'Green Day',
#  'View',
#  'Remy Boyz',
#  'Toni Braxton',
#  'Pendulum',
#  'Olivia Rodrigo',
#  'Eminem',
#  'Starley',
#  'PRETTYMUCH',
#  'NLE Choppa',
#  'Axwell',
#  'Getter Jaani',
#  'Luniz',
#  'The Royalties STHLM',
#  'Chimamanda Ngozi Adichie',
#  'Kodaline',
#  'Fuse ODG',
#  'Sam Martin',
#  'Aerosmith',
#  'Keri Hilson',
#  'Ilpo Kaikkonen',
#  'Cher',
#  'Ace of Base',
#  'Lakim',
#  'Mariska',
#  'Bobby Helms',
#  'Static Major',
#  '27CLUB',
#  'Setä Tamu',
#  'Blac Youngsta',
#  'Maija Vilkkumaa',
#  'N.W.A.',
#  'Smokepurpp',
#  'fun.',
#  'Within Temptation',
#  'Rik Rok',
#  'TWENTY88',
#  'duo',
#  'K CAMP',
#  'U2',
#  'Rune RK',
#  'Digital Farm Animals',
#  'Tiktak',
#  'G-Eazy',
#  'Madison Beer',
#  'Yo Gotti',
#  'twoloud',
#  'Mary Lambert',
#  'Conrad Sewell',
#  'Nicky Romero',
#  'Oliver Nelson',
#  'Hot Chelle Rae',
#  'Spongebob Squarepants',
#  'Tune Up!',
#  'Nick Jonas',
#  'Nina Sky',
#  'Bonn',
#  'Rejjie Snow',
#  'Emma Hewitt',
#  'Satin Circus',
#  'Ronya',
#  'Aya Nakamura',
#  'The Magician',
#  'YOUNGHEARTED',
#  '3 Doors Down',
#  'JoJo',
#  'Pihlaja',
#  'Crystal Castles',
#  'Manian',
#  'Kid Francescoli',
#  'Bridgit Mendler',
#  'Solo Lucci',
#  'Sam Feldt',
#  'Ty Dolla $ign',
#  'Ressu Redford',
#  'Arizona Zervas',
#  'Brendon Urie',
#  'Aimie Atkinson',
#  'Ruudolf',
#  '7ru7h',
#  'Bastille',
#  'Drake',
#  'Young Manager',
#  'Handsome Luke',
#  'Veela',
#  'Tory Lanez',
#  'Molchat Doma',
#  'ROSALÍA',
#  'Pyrythekid',
#  'Amy Diamond',
#  'Jacob Sartorius',
#  'Pykäri',
#  'Kenny Loggins',
#  'Cedric Gervais',
#  'Mally Mall',
#  'Raappana',
#  'Oliver Francis',
#  'Matt Squire',
#  'Kane Brown',
#  'Don Toliver',
#  'Kyla',
#  'Paul McCartney',
#  'Lil Pump',
#  'Lyttä',
#  'Leven Kali',
#  'Cheek',
#  'Naomi Scott',
#  'Sonique',
#  'KANDY',
#  'Molly Brazy',
#  'Pete Parkkonen',
#  'Richi M.',
#  'Wiz Khalifa',
#  'Matthew Koma',
#  'LMB DG',
#  'Pasi ja Anssi',
#  'Tom Walker',
#  'Musta-Lista',
#  'Iamsu!',
#  'Bekuh Boom',
#  'K-Slim',
#  'Julia Michaels',
#  'Dosdela',
#  'Young Thug',
#  'Dimitri Vegas',
#  'SHAUN',
#  'Thomas Jack',
#  'Edu Kettunen',
#  'Tyrone Briggs',
#  'Jake Reese',
#  'Erika Vikman',
#  'Lauv',
#  'Ella Eyre',
#  'Mvd Jeyson',
#  'Shakira',
#  'BONES',
#  'Rich Brian',
#  'Waka Flocka Flame',
#  'Don Diablo',
#  'Jessie Reyez',
#  'HesaÄijä',
#  'Ina Wroldsen',
#  'Eric Bellinger',
#  'INNA',
#  'Oliver Heldens',
#  'Mac Beez',
#  'Ozuna',
#  'Sami Saari',
#  'D/O',
#  'JACKBOYS',
#  'Dax',
#  'Char Ligera',
#  'The Saturdays',
#  'Famous Dex',
#  'Donny',
#  'Disclosure',
#  'Swell',
#  'Popcaan',
#  'dvsn',
#  'Freeman',
#  'MARINA',
#  'Sasha Lopez',
#  'Twenty One Pilots',
#  'Ryan Tedder',
#  'Frederik',
#  'Joseph',
#  'LSD',
#  'Kid Crave',
#  'The American Idiot Broadway Company',
#  'DaBaby',
#  'Liam Payne',
#  'Gary Jules',
#  'Priory',
#  'Tatarka',
#  'Lucas',
#  'Tacabro',
#  'Fasion',
#  'Alexis Jordan',
#  'Young Roc',
#  'Edwyn Collins',
#  'Travis Scott',
#  'Fifth Harmony',
#  'Young Nudy',
#  'The Chordettes',
#  'Olivia',
#  'Miriam Bryant',
#  'Mascara',
#  'Quando Rondo',
#  'Sueco',
#  'Chamillionaire',
#  'Neon 2',
#  'Loud Luxury',
#  'A Touch Of Class',
#  'Offset',
#  'Alex Joseph',
#  'Isaiah Firebrace',
#  'Gala',
#  'Lizzo',
#  'Skrillex',
#  'Moon Taxi',
#  'Jack McManus',
#  'Example',
#  'Ariana Grande',
#  'Ludacris',
#  'Train',
#  'Sofía Reyes',
#  'DISCO',
#  'BeatKing',
#  'Chris Lake',
#  'Molly',
#  'Haddaway',
#  'Lil Peep',
#  'Jon Bellion',
#  'Leo Stannard',
#  'Khalid',
#  'Craymer',
#  'Céline Dion',
#  'anders',
#  'Lucenzo',
#  'Niko Saarinen',
#  'Daler Mehndi',
#  'E-Rotic',
#  'Hector',
#  'W&W',
#  'Phil Collins',
#  'O-Zone',
#  'Vince Staples',
#  'Mamba',
#  'Rvssian',
#  'Jack Garratt',
#  'LUCA',
#  'Logic',
#  'Evang',
#  'Miranda Cosgrove',
#  'Jari Sillanpää',
#  'Black Veil Brides',
#  'Bass Modulators',
#  'Alex Aiono',
#  'SINI YASEMIN',
#  'Nicole Scherzinger',
#  'ILOVEMAKONNEN',
#  'Jonas Vogel',
#  'C & C Music Factory',
#  'Brennan Savage',
#  'Jamelia',
#  'Nytrix',
#  'Mac Miller',
#  'Maty Noyes',
#  'R. Kelly',
#  'Wintertime',
#  'Mellen Gi',
#  '50 Cent',
#  'Alfons',
#  'Jay Sean',
#  'Malmö',
#  'SEUNGRI',
#  'Maiki',
#  'Valvomo',
#  'Vicetone',
#  'Au/Ra',
#  'Vaahteramäen Nege',
#  'Mesto',
#  'Kelis',
#  'Emila',
#  'Katri Ylander',
#  'Spekti',
#  'Showtek',
#  'Nickelback',
#  'Popp Hunna',
#  'Daniel Powter',
#  'Indy & Karim',
#  'Death Grips',
#  'Prince Royce',
#  'Game of Thrones',
#  'BlocBoy JB',
#  'Laidback Luke',
#  'Kwabs',
#  'MYKKA',
#  'Alexander 23',
#  'Heavyweight',
#  'Trey Songz',
#  'Jesse Kaikuranta',
#  'BROCKHAMPTON',
#  'Samuli Edelmann',
#  'James Blake',
#  'DJ Antoine',
#  'Adizi X Typelik',
#  'Savage Ga$p',
#  'Lloyd Banks',
#  'Vika Jigulina',
#  'FLETCHER',
#  '24hrs',
#  'Calboy',
#  'Miranda',
#  'Touko',
#  'Krista Siegfrids',
#  'Irina',
#  'Cover Drive',
#  'Anastacia',
#  'Janelle Monáe',
#  'Michael Jackson',
#  'Tarrus Riley',
#  'Dragonette',
#  'ODEE',
#  'David Guetta',
#  'Mariska & Pahat Sudet',
#  'Jennifer Lopez',
#  'Arctic Monkeys',
#  'alt-J',
#  'Matisyahu',
#  'ALMA',
#  'Meek Mill',
#  'Rixton',
#  'LVNDSCAPE',
#  'Horse Attack Sqwad',
#  'Lauri Tähkä & Elonkerjuu',
#  'DripReport',
#  'Kayla Nicole',
#  'Ivone Cerdan',
#  'Project.M',
#  'Arron',
#  'Temur',
#  'Troye Sivan',
#  'Sammie',
#  'Lindsey Stirling',
#  'Kim Herold',
#  'Ori',
#  'Jessie J',
#  'Vepu',
#  'Pet Shop Boys',
#  'Whethan',
#  'ibe',
#  'All Time Low',
#  'Kristal',
#  'Jeffrey James',
#  'Freshlyground',
#  'Roddy Ricch',
#  'French Montana',
#  'Bebe Rexha',
#  'Estelle',
#  'Brädi',
#  'Getter',
#  'Lauren Bennett',
#  'Maroon 5',
#  "Gigi D'Agostino",
#  'Mindless Self Indulgence',
#  'Cashmere Cat',
#  'Eppu Normaali',
#  'Miguel',
#  'Blake Michael',
#  'Audrey Mika',
#  'Tez Cadey',
#  'Sak Noel',
#  'J. Cole',
#  'Macklemore',
#  'Sexmane',
#  'Halestorm',
#  'Aloe Blacc',
#  'Kid Ink',
#  'ZAYN',
#  'Donkeyboy',
#  'KSI',
#  'Anna Eriksson',
#  'Machine Gun Kelly',
#  'Vastis',
#  'Capital Cities',
#  'Dash Berlin',
#  ...]

# %% [markdown]
# ## Artists ID

# %%
def get_artists_from_track(track):
    return[artist["name"] for artist in track["artists"]]

#--------------------------------------------------------------------

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
def get_artists_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_ids_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
len(artists)
len(artists_ids) # We might have more ids due to artists having the same name
# Out:
# 2439

# %% [markdown]
# # Getting the info

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'BTS',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Banda de Música da Força Aérea',
#  'Coldplay',
#  'David Guetta',
#  'Galantis',
#  'Greta Bradman',
#  'Jon Hopkins',
#  'José Manuel Ferreira Brito',
#  'Ofenbach',
#  'Rhythms Del Mundo',
#  'Rihanna',
#  'Robin Schulz',
#  'SUGA',
#  'Seeb',
#  'Selena Gomez',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'Yotto',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 67264
